# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
# load dataset
data = pd.read_csv("c_dataset.csv")
#take a peek to see if this looks right
data.head()
# Out:
#    popularity  duration_ms  explicit  danceability  energy  key  loudness  \
# 0          55       149610         0         0.420  0.1660    1   -17.235
# 1          57       210826         0         0.438  0.3590    0    -9.734
# 2          71       201933         0         0.266  0.0596    0   -18.515
# 3          82       198853         0         0.618  0.4430    2    -9.681
# 4          58       214240         0         0.688  0.4810    6    -8.807
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0763         0.924          0.000006    0.1010    0.267
# 1     1       0.0557         0.210          0.000000    0.1170    0.120
# 2     1       0.0363         0.905          0.000071    0.1320    0.143
# 3     1       0.0526         0.469          0.000000    0.0829    0.167
# 4     1       0.1050         0.289          0.000000    0.1890    0.666
#
#      tempo  time_signature  track_genre
# 0   77.489               4          1.0
# ...

# %%
#split dataset in features and target variable
X = data[data.columns[:-1]] # Features
y = data['popularity'] # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) 
# 70% training and 30% test

# %%
# Create Decision Tree classifer object
dtc = DecisionTreeClassifier()

# %%
# Train Decision Tree Classifer
model = dtc.fit(X_train,y_train)

# %%
#Predict the response for test dataset
y_pred = dtc.predict(X_test)

# %%
#predict the response for the training set
train_predict = dtc.predict(X_train)

# %%
# Are you overfitting?
print(f"Accuracy train:{metrics.accuracy_score(y_train, train_predict)}")
print(f"Accuracy test:{metrics.accuracy_score(y_test, y_pred)}")
# Out:
# Accuracy train:1.0
# Accuracy test:1.0

# %% [markdown]
# ### Answer this question in a markdown cell, clearly labeling your answer to the question.
# 1. Is your model overfitting?  How do you know?
#        It seem as if the modle is overfitting. You can tell this by the training and test data being at 100.

# %%
# Import necessary libraries
from six import StringIO
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# Define the feature columns (update to match your dataset)
feature_cols = ['duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode', 
                'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 
                'time_signature', 'track_genre']

# Prepare your data
X = data[feature_cols]  # Features
y = data['popularity']  # Target variable

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# Train the Decision Tree Classifier
dtc = DecisionTreeClassifier()
model = dtc.fit(X_train, y_train)

# Generate visualization for the Decision Tree
dot_data = StringIO()
export_graphviz(
    model,
    out_file=dot_data,
    filled=True,
    rounded=True,
    special_characters=True,
    feature_names=feature_cols,
    class_names=[str(cls) for cls in y.unique()]  # assuming classes are unique values in 'popularity'
)

# Create and display the tree graph
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('popularity_tree.png')
Image(graph.create_png())

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Create Decision Tree classifier object using entropy for picking the best feature
entroTree = DecisionTreeClassifier(criterion="entropy")

# Train the Decision Tree Classifier
entroTree.fit(X_train, y_train)

# Predict the response for the test dataset
y_pred = entroTree.predict(X_test)

# Predict the response for the training dataset (to evaluate training accuracy)
train_predict = entroTree.predict(X_train)

# Model Accuracy: how often is the classifier correct?
print(f"Accuracy on training set: {accuracy_score(y_train, train_predict)}")
print(f"Accuracy on test set: {accuracy_score(y_test, y_pred)}")

# %%
from six import StringIO
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
feature_cols = ['duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode', 
                'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'track_genre']

dot_data = StringIO()
export_graphviz(
    entroTree, 
    out_file=dot_data,  
    filled=True, 
    rounded=True,
    special_characters=True, 
    feature_names=feature_cols,
    class_names=[str(cls) for cls in y.unique()]  # Unique classes in your target variable
)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('popularity_tree_entropy.png')
Image(graph.create_png())

# %% [markdown]
# # DID NOT UPDATA THIS WORDS
# Answer these questions in a markdown cell, clearly labeling your answers to the questions.
#
# 1. Did you get different results using entropy compared to when you used the Gini index as the criterion for picking the best feature?
#        --Yes, I got 0.02% better when using entropy. Which is good when Accuracy train is at 100%
# 3. It is hard to have a strong opinion when I have only seen them played out ones. But at the moment I think that entropy is a better module to use. With the little background that I have. I think it is better with entropy because it gets more to my main data.
# 5. Are the first top layers of your trees similar or different (it may be easier to look at the png files that trying to see that in your notebook)?
#    	The Gini and entropy have very different numbers. The other numbers in the graph are not really too different. The big difference is that Gini vs. entropy
# 7.  Is your model using entropy as the criterion overfitting?  How do you know?
#  	It is overiffing because of the criterion we know this from looking at the graph images because they are different in that regard.

# %%
# Create Decision Tree classifer object
short = DecisionTreeClassifier(criterion="entropy", max_depth=3)

# Train Decision Tree Classifer
short = short.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = short.predict(X_test)

train_predict = short.predict(X_train)

# Model Accuracy, how often is the classifier correct?
print(f"Accuracy train:{metrics.accuracy_score(y_train, train_predict)}")
print(f"Accuracy test:{metrics.accuracy_score(y_test, y_pred)}")
#print(f"Accuracy on training set: {accuracy_score(y_train, train_predict)}")
#print(f"Accuracy on test set: {accuracy_score(y_test, y_pred)}")

# %%
from six import StringIO  #
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(short, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names = feature_cols,class_names=[str(cls) for cls in y.unique()]
               )
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('early_diabetes_maxDepth_3.png')
Image(graph.create_png())

# %% [markdown]
# # DID NOT UPDATE THIS INFO
# Answer these questions in a markdown cell, clearly labeling your answers to the questions.
# 1. Did the height of the tree impact the accuracy of your model on your testing and training sets?
#    	--Over all the numbers in the model are not different. But it does seem that the Accuracy train:0.9038461538461539 and Accuracy test:0.8974358974358975 both of these numbers are not as high as the other tree that is taller.
# 3. Is your model with the shorter tree overfitting?  How do you know?
#   	 --No, I believe that is not overfitting because the Accuracy train and Accuracy test are very simmlyer
# 5. How do the accuracy scores of the Decision Tree models compare the accuracy of the model you created using the Naïve Bayesian classifier?
#     --	Using the Naïve Bayesian classifier test and accuracy scouse are the closes out of all the trees so far. This is good showing that overfitting is small in this regard.
# 6. Is your model good given the context of medical diagnosis?
#    	--I belive that even given the context the modle is so small that it still would not be super good to use in a real world setting.

# %% [markdown]
# import pandas as pd                    #NEWONE
# from sklearn.model_selection import train_test_split
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.metrics import accuracy_score
# from six import StringIO
# from IPython.display import Image
# from sklearn.tree import export_graphviz
# import pydotplus
#
# # Column names in your dataset
# col_names = [
#     'popularity', 'duration_ms', 'explicit', 'danceability', 'energy', 'key',
#     'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#     'liveness', 'valence', 'tempo', 'time_signature', 'track_genre'
# ]
#
# # Load your dataset
# data = pd.read_csv("your_file_name.csv", header=None, names=col_names)
#
# # Define feature columns (all except the target)
# feature_cols = [
#     'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#     'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#     'valence', 'tempo', 'time_signature', 'track_genre'
# ]
#
# # Split dataset into features and target variable
# X = data[feature_cols]  # Features
# y = data['popularity']  # Target variable
#
# # Split dataset into training set and test set
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
#
# # Create Decision Tree classifier object
# dtc = DecisionTreeClassifier()
#
# # Train Decision Tree Classifier
# model = dtc.fit(X_train, y_train)
#
# # Predict the response for test dataset
# y_pred = dtc.predict(X_test)
#
# # Predict the response for the training set
# train_predict = dtc.predict(X_train)
#
# # Model Accuracy, how often is the classifier correct?
# print(f"Accuracy on training set: {accuracy_score(y_train, train_predict)}")
# print(f"Accuracy on test set: {accuracy_score(y_test, y_pred)}")
#
# # Visualize the Decision Tree
# class_names = [str(i) for i in sorted(data['popularity'].unique())]
# dot_data = StringIO()
# export_graphviz(
#     model,
#     out_file=dot_data,
#     filled=True,
#     rounded=True,
#     special_characters=True,
#     feature_names=feature_cols,
#     class_names=class_names
# )
#
# # Create and display the tree graph
# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# graph.write_png('popularity_tree.png')
# Image(graph.create_png())

# %%
#from: https://archive.ics.uci.edu/dataset/33/dermatology    OLDONE
#make sure you have your labels correct
#some files have this in the file - others it is in the description
#if it is in the file you can copy them here then delete that line in the file
col_names = ['erythema', 'scaling', 'definite_borders', 'itching', ' koebner_phenomenon', 'polygonal_papules', 'follicular_papules', 'oral_mucosal_involvement',  'knee_and_elbow_involvement', 'scalp_involvement', 'family_history', ' melanin_incontinence', 'eosinophils_in_the_infiltrate', 'PNL_infiltrate', 'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis', 'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges', 'elongation_of_the_rete_ridges', 'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule', 'munro_microabcess', 'focal_hypergranulosis', 'disappearance_of_the_granular_layer', 'vacuolisation_and_damage_of_basal_layer' ,'spongiosis', 'saw-tooth_appearance_of_retes','follicular_horn_plug', 'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate', 'band-like_infiltrate', 'age','outcome']
# load dataset
data = pd.read_csv("dermatology.csv", header=None, names=col_names)
#take a peak to see if this looks right
#data.head() #optional

#split dataset in features and target variable
feature_cols = ['erythema', 'scaling', 'definite_borders', 'itching', ' koebner_phenomenon', 'polygonal_papules', 'follicular_papules', 'oral_mucosal_involvement',  'knee_and_elbow_involvement', 'scalp_involvement', 'family_history', ' melanin_incontinence', 'eosinophils_in_the_infiltrate', 'PNL_infiltrate', 'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis', 'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges', 'elongation_of_the_rete_ridges', 'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule', 'munro_microabcess', 'focal_hypergranulosis', 'disappearance_of_the_granular_layer', 'vacuolisation_and_damage_of_basal_layer' ,'spongiosis', 'saw-tooth_appearance_of_retes','follicular_horn_plug', 'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate', 'band-like_infiltrate', 'age']
X = data[feature_cols] # Features
y = data['outcome'] # Target variable

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# Create Decision Tree classifer object
dtc = DecisionTreeClassifier()

# Train Decision Tree Classifer
model = dtc.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = dtc.predict(X_test)

#predict the response for the training set
train_predict = dtc.predict(X_train)

# Model Accuracy, how often is the classifier correct?
# Are you overfitting?
print(f"Accuracy train:{metrics.accuracy_score(y_train, train_predict)}")
print(f"Accuracy test:{metrics.accuracy_score(y_test, y_pred)}")

#Look at your tree
from six import StringIO
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
class_names = [str(i) for i in sorted(data['outcome'].unique())]
dot_data = StringIO()
export_graphviz(model, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names = feature_cols,class_names=class_names)
            
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('dermDefaultTree.png')
Image(graph.create_png())

# %%
import pandas as pd
fdata:image/png;base64,... sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from six import StringIO
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# Load Air Quality UCI dataset
col_names = ['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']

# Read the CSV and handle missing values
data = pd.read_csv("AirQualityUCI.csv", delimiter=';', usecols=range(15), na_values=-200)

# Replace commas with periods only for columns that are of type string (object)
for col in col_names[2:]:  # Skip 'Date' and 'Time' columns
    if data[col].dtype == 'object':
        data[col] = data[col].str.replace(',', '.').astype(float)

# Drop rows with missing values (optional)
data.dropna(inplace=True)

data['CO(GT)_category'] = pd.cut(data['CO(GT)'], bins=[0, 1, 5, 10], labels=['Low', 'Medium', 'High'])


# Select feature columns   'CO(GT)',
feature_cols = ['PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']
X = data[feature_cols]  # Features

# For simplicity, let's assume the target is predicting air quality based on one of the sensor readings
y = data['CO(GT)_category']  # Categorical target variable

# Split dataset into training set and test set (70% training and 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# Create Decision Tree Classifier object
dtc = DecisionTreeClassifier()

# Train the classifier
model = dtc.fit(X_train, y_train)

# Predict on test dataset
y_pred = dtc.predict(X_test)

# Predict on training set to check for overfitting
train_predict = dtc.predict(X_train)

# Output accuracy
print(f"Default Decision tree")
print(f"Accuracy train: {metrics.accuracy_score(y_train, train_predict)}")
print(f"Accuracy test: {metrics.accuracy_score(y_test, y_pred)}")

# Visualize the decision tree
class_names = [str(i) for i in sorted(data['CO(GT)'].unique())]
dot_data = StringIO()
export_graphviz(model, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names=feature_cols, class_names=class_names)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('airQualityTree.png')
Image(graph.create_png())

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from six import StringIO
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# Load Air Quality UCI dataset
col_names = ['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']

# Read the CSV and handle missing values
data = pd.read_csv("AirQualityUCI.csv", delimiter=';', usecols=range(15), na_values=-200)

# Replace commas with periods only for columns that are of type string (object)
for col in col_names[2:]:  # Skip 'Date' and 'Time' columns
    if data[col].dtype == 'object':
        data[col] = data[col].str.replace(',', '.').astype(float)

# Drop rows with missing values (optional)
data.dropna(inplace=True)

# Discretize CO(GT) into categories: Low, Medium, High
data['CO(GT)_category'] = pd.cut(data['CO(GT)'], bins=[0, 1, 5, 10], labels=['Low', 'Medium', 'High'])

# Select feature columns  'CO(GT)',
feature_cols = ['PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']
X = data[feature_cols]  # Features

# Target variable
y = data['CO(GT)_category']  # Categorical target variable

# Split dataset into training set and test set (70% training and 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# Create Decision Tree Classifier object with entropy as the criterion and max_depth of 5
dtc = DecisionTreeClassifier()

# Train the classifier
model = dtc.fit(X_train, y_train)

# Predict on test dataset
y_pred = dtc.predict(X_test)

# Predict on training set to check for overfitting
train_predict = dtc.predict(X_train)

# Output accuracy
print(f"Decision Tree with Entropy")
print(f"Accuracy train: {metrics.accuracy_score(y_train, train_predict)}")
print(f"Accuracy test: {metrics.accuracy_score(y_test, y_pred)}")

# Visualize the decision tree
class_names = ['Low', 'Medium', 'High']
dot_data = StringIO()
export_graphviz(model, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names=feature_cols, class_names=class_names)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('airQualityTree.png')
Image(graph.create_png())

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from six import StringIO
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# Load Air Quality UCI dataset
col_names = ['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']

# Read the CSV and handle missing values
data = pd.read_csv("AirQualityUCI.csv", delimiter=';', usecols=range(15), na_values=-200)

# Replace commas with periods only for columns that are of type string (object)
for col in col_names[2:]:  # Skip 'Date' and 'Time' columns
    if data[col].dtype == 'object':
        data[col] = data[col].str.replace(',', '.').astype(float)

# Drop rows with missing values (optional)
data.dropna(inplace=True)

data['CO(GT)_category'] = pd.cut(data['CO(GT)'], bins=[0, 1, 5, 10], labels=['Low', 'Medium', 'High'])

# Select feature columns    'CO(GT)',
feature_cols = ['PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']
X = data[feature_cols]  # Features

# Target variable
y = data['CO(GT)_category']  # Categorical target variable

# Split dataset into training set and test set (70% training and 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# Create Decision Tree Classifier object with max_depth of 5
dtc = DecisionTreeClassifier(max_depth=5)

# Train the classifier
model = dtc.fit(X_train, y_train)

# Predict on test dataset
y_pred = dtc.predict(X_test)

# Predict on training set to check for overfitting
train_predict = dtc.predict(X_train)

# Output accuracy
print(f"Decision Tree max_depth = 5")
print(f"Accuracy train: {metrics.accuracy_score(y_train, train_predict)}")
print(f"Accuracy test: {metrics.accuracy_score(y_test, y_pred)}")

# Visualize the decision tree
class_names = ['Low', 'Medium', 'High']
dot_data = StringIO()
export_graphviz(model, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names=feature_cols, class_names=class_names)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('airQualityTree.png')
Image(graph.create_png())

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from six import StringIO
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# Load Air Quality UCI dataset
col_names = ['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']

# Read the CSV and handle missing values
data = pd.read_csv("AirQualityUCI.csv", delimiter=';', usecols=range(15), na_values=-200)

# Replace commas with periods only for columns that are of type string (object)
for col in col_names[2:]:  # Skip 'Date' and 'Time' columns
    if data[col].dtype == 'object':
        data[col] = data[col].str.replace(',', '.').astype(float)

# Drop rows with missing values (optional)
data.dropna(inplace=True)

data['CO(GT)_category'] = pd.cut(data['CO(GT)'], bins=[0, 1, 5, 10], labels=['Low', 'Medium', 'High'])

# Select feature columns    'CO(GT)', 
feature_cols = ['PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']
X = data[feature_cols]  # Features

# Target variable
y = data['CO(GT)_category']  # Categorical target variable

# Split dataset into training set and test set (70% training and 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# Create Decision Tree Classifier object with max_depth of 8
dtc = DecisionTreeClassifier(max_depth=8)

# Train the classifier
model = dtc.fit(X_train, y_train)

# Predict on test dataset
y_pred = dtc.predict(X_test)

# Predict on training set to check for overfitting
train_predict = dtc.predict(X_train)

# Output accuracy
print(f"Decision Tree max_depth = 8")
print(f"Accuracy train: {metrics.accuracy_score(y_train, train_predict)}")
print(f"Accuracy test: {metrics.accuracy_score(y_test, y_pred)}")

# Visualize the decision tree
class_names = ['Low', 'Medium', 'High']
dot_data = StringIO()
export_graphviz(model, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names=feature_cols, class_names=class_names)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('airQualityTree.png')
Image(graph.create_png())

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from six import StringIO
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
from sklearn import tree

# Load Air Quality UCI dataset
col_names = ['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']

# Read the CSV and handle missing values
data = pd.read_csv("AirQualityUCI.csv", delimiter=';', usecols=range(15), na_values=-200)

# Replace commas with periods only for columns that are of type string (object)
for col in col_names[2:]:  # Skip 'Date' and 'Time' columns
    if data[col].dtype == 'object':
        data[col] = data[col].str.replace(',', '.').astype(float)

# Drop rows with missing values (optional)
data.dropna(inplace=True)

data['CO(GT)_category'] = pd.cut(data['CO(GT)'], bins=[0, 1, 5, 10], labels=['Low', 'Medium', 'High'])

# Select feature columns    'CO(GT)', 
feature_cols = ['PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)', 'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)', 'PT08.S5(O3)', 'T', 'RH', 'AH']
X = data[feature_cols]  # Features

# Target variable
y = data['CO(GT)_category']  # Categorical target variable

# Split dataset into training set and test set (70% training and 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# Create Decision Tree Classifier object with max_depth of 13
dtc = DecisionTreeClassifier(max_depth=13)

# Train the classifier
model = dtc.fit(X_train, y_train)

# Predict on test dataset
y_pred = dtc.predict(X_test)

# Predict on training set to check for overfitting
train_predict = dtc.predict(X_train)

# Output accuracy
print(f"Decision Tree max_depth = 13")
print(f"Accuracy train: {metrics.accuracy_score(y_train, train_predict)}")
print(f"Accuracy test: {metrics.accuracy_score(y_test, y_pred)}")
print(tree.export_text(dtc, feature_names=feature_cols))

# Visualize the decision tree
class_names = ['Low', 'Medium', 'High']
dot_data = StringIO()
export_graphviz(model, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names=feature_cols, class_names=class_names)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('airQualityTree.png')
Image(graph.create_png())

# %% [markdown]
# Tasks for you to do and label:
#     • Select a dataset that uses numeric values for its attributes.  If they are not numeric – you will need to use techniques to convert the values to numeric values.  A: They were Numeric
#
#
#      *Build a decision tree using the default attributes.
#     • Then repeat the process altering the criterion to use entropy. Report its accuracy.
#     • Explore varying heights of trees (use at least 3 different max_depths). Report their accuracy values.   Your goal: create the most accurate model that does not overfit your training data.
#     • Report the setting for your best tree.
